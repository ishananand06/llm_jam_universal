# %% [markdown]
# # Task 1 — Query Class Validation
#
# Validates the paraphrase and entity query classes built in Steps 2–3.
#
# **What to do:**
# 1. Run all cells.
# 2. In the **Manual Rating** sections, update the `ratings` dicts with your 1–5 scores.
# 3. Re-run the summary cells to get final statistics.
# 4. Copy the printed summary into `results/task1_class_validation.md`.

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path('/home/ishana/scratch/data/classes')

with open(DATA_DIR / 'paraphrase_classes.json') as f:
    para_classes = json.load(f)

with open(DATA_DIR / 'entity_classes.json') as f:
    entity_classes = json.load(f)

para_embs = np.load(DATA_DIR / 'paraphrase_embeddings.npy')   # (100, 6, 1024)
entity_embs = np.load(DATA_DIR / 'entity_embeddings.npy')      # (20, max_size, 1024)

print(f'Paraphrase classes: {len(para_classes)}')
print(f'Entity classes:     {len(entity_classes)}')
print(f'Para embeddings:    {para_embs.shape}')
print(f'Entity embeddings:  {entity_embs.shape}')
# Out:
# Paraphrase classes: 100
# Entity classes:     20
# Para embeddings:    (100, 6, 1024)
# Entity embeddings:  (20, 8, 1024)

# %% [markdown]
# ---
# ## Part 1 — Paraphrase Classes
#
# Showing 20 random classes. Rate each 1–5:
# - **5** = All paraphrases clearly ask the exact same thing
# - **4** = Mostly good, one minor deviation
# - **3** = Acceptable but noticeable differences
# - **2** = Several paraphrases drift in meaning
# - **1** = Not paraphrases at all

# %%
random.seed(42)
sample_indices = sorted(random.sample(range(len(para_classes)), 20))
sample_para = [(i, para_classes[i]) for i in sample_indices]

for rank, (idx, cls) in enumerate(sample_para, 1):
    sim = cls['within_class_similarity']
    print(f"[{rank:02d}] idx={idx}  sim={sim:.3f}")
    print(f"  Original: {cls['original_query']}")
    for j, p in enumerate(cls['paraphrases'], 1):
        print(f"  {j}. {p}")
    print()
# Out:
# [01] idx=3  sim=0.871
#   Original: who makes the decisions about what to produce in a market economy
#   1. In a market economy, who is responsible for determining what goods and services are produced?
#   2. Who has the authority to decide what products are manufactured in a market-based economic system?
#   3. In a market economy, who gets to decide which goods and services are produced?
#   4. Who is in charge of deciding the types of goods that are produced in a market-driven economy?
#   5. What entities or individuals make the decisions regarding the production of goods and services in a market economy?
#
# [02] idx=4  sim=0.927
#   Original: when is the new tappan zee bridge going to be finished
#   1. What is the estimated completion date for the new Tappan Zee Bridge?
#   2. At what point in time will the construction of the new Tappan Zee Bridge be completed?
#   3. Can you tell me when the Tappan Zee Bridge replacement project is predicted to be finished?
#   4. When does the construction of the new Tappan Zee Bridge project anticipate being completed?
#   5. What is the projected completion date for the new Tappan Zee Bridge?
#
# [03] idx=11  sim=0.903
#   Original: where are the mitochondria located in the sperm
#   1. In which part of the sperm cell are the mitochondria situated?
#   2. Do mitochondria in the sperm reside in a specific cell component?
#   3. Where precisely are the mitochondria placed within a sperm cell?
#   4. What part of the sperm contains the mitochondria?
#   5. Where exactly are mitochondria positioned within the structure of a sperm cell?
#
# [04] idx=13  sim=0.889
#   Original: how many seasons of the oc are there
#   1. How many seasons of The O.C. are there in total?
#   2. What is the total number of seasons of The O.C.?
#   3. How many seasons of the popular television series The O.C. are there?
#   4. What is the season count of the television show The O.C.?
#   5. In how many seasons did the television series The O.C. run?
#
# [05] idx=14  sim=0.855
#   Original: latest season on keeping up with the kardashians
#   1. What is the latest season available for watching Keeping Up with the Kardashians?
#   2. Which episode is the most recent in the Keeping Up with the Kardashians series?
#   3. What's the most up-to-date season of Keeping Up with the Kardashians?
#   4. Can you tell me the most recent season of the reality TV show Keeping Up with the Kardashians?
#   5. What is the current season being shown on the reality TV series Keeping Up with the Kardashians?
#
# [06] idx=17  sim=0.935
#   Original: does joe die in the purge election year
#   1. Does Joe meet his demise in The Purge: Election Year?
#   2. Is Joe a casualty in The Purge: Election Year?
#   3. Does Joe lose his life in The Purge: Election Year?
#   4. Does Joe die in the events of The Purge: Election Year?
#   5. In The Purge: Election Year, does Joe ultimately perish?
#
# [07] idx=27  sim=0.900
#   Original: who performed the first c section in 1794
#   1. Who conducted the first c section in the year 1794?
#   2. Who led the first c section in 1794?
#   3. Who was in charge of the first c section during 1794?
#   4. Who gave the first c section performance in 1794?
#   5. Who was responsible for the inaugural c section in 1794?
#
# [08] idx=28  sim=0.912
#   Original: who sang in the movie i walk the line
#   1. Who performed in the film I Walk the Line?
#   2. Who starred as a singer in the movie I Walk the Line?
#   3. Who was the singer in the movie I Walk the Line?
#   4. In the movie I Walk the Line, who played a singing role?
#   5. Who was the musician in the movie I Walk the Line?
#
# [09] idx=29  sim=0.952
#   Original: where did aeneas go when he left carthage
#   1. What location did Aeneas depart to after leaving Carthage?
#   2. Where did Aeneas travel to after abandoning Carthage?
#   3. To which destination did Aeneas depart from Carthage?
#   4. What was the place that Aeneas went to after leaving behind Carthage?
#   5. Where did Aeneas head to upon leaving Carthage?
#
# [10] idx=31  sim=0.923
#   Original: who plays general hux in the last jedi
#   1. Who portrays the character of General Hux in the latest Star Wars film, The Last Jedi?
#   2. In the movie The Last Jedi, who acts out the role of General Hux?
#   3. Who was the actor behind General Hux in The Last Jedi?
#   4. Which actor brought General Hux to life in the Star Wars film The Last Jedi?
#   5. Who assumed the role of General Hux in the 2017 movie The Last Jedi?
#
# [11] idx=35  sim=0.871
#   Original: who starred in the remake of true grit
#   1. Who played the lead role in the remake of True Grit?
#   2. Who was cast in the film adaptation of True Grit?
#   3. In the redo of True Grit, who was the main actor?
#   4. Who portrayed the primary character in the new version of True Grit?
#   5. Who acted in the remake of the movie True Grit?
#
# [12] idx=54  sim=0.912
#   Original: what are some elements that are similar to silver
#   1. What are some materials that share characteristics with silver?
#   2. What substances have properties comparable to those of silver?
#   3. Are there any elements that have similarities to silver?
#   4. What other elements exhibit qualities similar to silver?
#   5. Do any elements have features in common with silver?
#
# [13] idx=64  sim=0.930
#   Original: what is the origin of the name marilyn
#   1. Where did the name Marilyn originate from?
#   2. What is the origin story of Marilyn as a given name?
#   3. Where did the name Marilyn come from in terms of its etymology?
#   4. What is the history behind the name Marilyn?
#   5. How did the name Marilyn get its start in terms of its origins?
#
# [14] idx=69  sim=0.799
#   Original: who was the last nba player to get drafted out of high school
#   1. Who was the most recent NBA player to enter the league directly from high school?
#   2. Which player was chosen by the NBA from high school in their final draft?
#   3. Who is the newest NBA player to skip college and enter the league straight from high school?
#   4. Who was the last individual to be drafted by the NBA before attending college?
#   5. Who was the final high school student selected in the NBA draft?
#
# [15] idx=71  sim=0.916
#   Original: difference between judge and justice of the peace
#   1. What is the distinction between a judge and a justice of the peace?
#   2. How do judges and justices of the peace differ?
#   3. What are the key differences between a judge and a justice of the peace?
#   4. Can you explain the difference between a person who is a judge and one who is a justice of the peace?
#   5. In what ways do judges and justices of the peace diverge in their roles and responsibilities?
#
# [16] idx=75  sim=0.820
#   Original: what is the name of the restaurant in seinfeld
#   1. What was the name of the restaurant featured in Seinfeld?
#   2. In the television show Seinfeld, what was the name of that famous eating place?
#   3. What is the name of Jerry's favorite hangout in the popular TV series Seinfeld?
#   4. What was the name of the restaurant that Jerry and his friends frequently visited?
#   5. In the sitcom Seinfeld, what was the name of the restaurant that became a recurring theme?
#
# [17] idx=77  sim=0.942
#   Original: when did the log flume closed at alton towers
#   1. At what point in time did the log flume shut down at Alton Towers?
#   2. When did the log flume ride stop operating at Alton Towers?
#   3. When was the log flume at Alton Towers closed to the public?
#   4. On what date did the log flume ride cease to operate at Alton Towers?
#   5. When did the log flume attraction close at Alton Towers theme park?
#
# [18] idx=81  sim=0.932
#   Original: who sang the theme song for laverne and shirley
#   1. Who performed the Laverne and Shirley theme song?
#   2. Who was the vocal artist behind the Laverne and Shirley theme?
#   3. Who did the singing for Laverne and Shirley's theme song?
#   4. What singer recorded the iconic theme song for Laverne and Shirley?
#   5. Who was the singer who sang the famous theme song for Laverne and Shirley?
#
# [19] idx=86  sim=0.899
#   Original: who sang how can you mend a broken heart first
#   1. Who was the artist behind the song "How Can You Mend a Broken Heart?"
#   2. Who recorded the song "How Can You Mend a Broken Heart"?
#   3. Which musician performed the song "How Can You Mend a Broken Heart"?
#   4. What artist made the song "How Can You Mend a Broken Heart" famous?
#   5. Who wrote and performed the hit song "How Can You Mend a Broken Heart"?
#
# [20] idx=94  sim=0.914
#   Original: what year did the golden state warriors win their first nba championship
#   1. In what year did the Golden State Warriors initially claim the NBA championship title?
#   2. When did the Golden State Warriors achieve their first ever NBA championship victory?
#   3. What was the year the Golden State Warriors won their inaugural NBA championship?
#   4. At what point in time did the Golden State Warriors secure their first NBA championship?
#   5. In which year did the Golden State Warriors capture their first NBA championship award?

# %%
# ── FILL IN YOUR RATINGS HERE (1–5 per class, in display order) ──────────────
# Keys are the rank numbers shown above (1–20).
# Replace None with your rating after reviewing each class.

para_ratings = {
     1: None,
     2: None,
     3: None,
     4: None,
     5: None,
     6: None,
     7: None,
     8: None,
     9: None,
    10: None,
    11: None,
    12: None,
    13: None,
    14: None,
    15: None,
    16: None,
    17: None,
    18: None,
    19: None,
    20: None,
}

# %%
# Paraphrase rating summary
rated = {k: v for k, v in para_ratings.items() if v is not None}
if rated:
    scores = list(rated.values())
    print(f'Rated {len(rated)}/20 paraphrase classes')
    print(f'Mean rating:  {np.mean(scores):.2f} / 5.0')
    print(f'Median:       {np.median(scores):.1f}')
    print(f'Distribution: {dict(sorted((v, scores.count(v)) for v in set(scores)))}')
    print(f'Pass (≥4.0): {"YES" if np.mean(scores) >= 4.0 else "NO"}')
else:
    print('No ratings yet — fill in para_ratings above.')
# Out:
# No ratings yet — fill in para_ratings above.

# %% [markdown]
# ---
# ## Part 2 — Entity Classes
#
# Showing all 20 entity classes. Rate each 1–5:
# - **5** = Clearly all about the same entity, coherent group
# - **4** = Good grouping, minor entity ambiguity
# - **3** = Acceptable but entity is too broad (e.g. 'China' mixes history/culture/geography)
# - **2** = Some queries don't belong
# - **1** = Incoherent grouping

# %%
for rank, cls in enumerate(entity_classes, 1):
    sim = cls['within_class_similarity']
    print(f"[{rank:02d}] entity='{cls['primary_entity']}'  size={cls['size']}  sim={sim:.3f}")
    for q in cls['queries']:
        print(f"  - {q}")
    print()
# Out:
# [01] entity='China'  size=8  sim=0.529
#   - how many kilometers of great wall of china
#   - when was the abacus invented in ancient china
#   - first day collection of mission china assamese film
#   - china in chinese is called zhongguo which means
#   - an influential religion to enter china along the silk route during the han dynasty was
#   - what dynasty completed the great wall of china
#   - when did one child policy end in china
#   - which two regions grow most of china’s rice
#
# [02] entity='Congress'  size=8  sim=0.581
#   - when did the continental congress vote to adopt the declaration of independence
#   - congress controls the number of federal district and federal circuit courts that exist
#   - must each house of congress publish all of its proceedings
#   - when is the last time congress passed a complete budget
#   - a legislative act passed by congress is an example of
#   - who laid the foundation for indian national congress
#   - creating appropriation bills falls under which power of congress
#   - in 1973 congress passed the war powers resolution to
#
# [03] entity='Australia'  size=8  sim=0.552
#   - when does wentworth season 6 start in australia
#   - is australia the largest island in the world
#   - what is the legal age for marriage in australia
#   - the vast interior rural area of australia is known as the
#   - who are the australia's got talent judges
#   - when did university stop being free in australia
#   - what is australia's location in the world and region
#   - when did the first fleet arive in australia
#
# [04] entity='Nba'  size=7  sim=0.630
#   - nba record for most double doubles in a season
#   - who was the last nba player to get drafted out of high school
#   - what year did the golden state warriors win their first nba championship
#   - who scored the most points in a game nba history
#   - when was the last time an nba backboard broken
#   - who votes for nba defensive player of year
#   - when did the nba start playing zone defense
#
# [05] entity='Britain'  size=7  sim=0.547
#   - who won the battle of britain in ww2
#   - when did canada gain independence from great britain
#   - when did the vikings first sail and reach britain
#   - when did britain set up east indian trading company
#   - what was the general goal of imperial powers such as great britain in the late nineteenth century
#   - where is the battle of britain flight based
#   - what elements make up great britain's constitution
#
# [06] entity='Nfl'  size=7  sim=0.608
#   - what nfl coach has the most wins ever
#   - who has the most super bowls in nfl history
#   - how long is training camp for nfl players
#   - what nfl team has the most expensive super bowl ring
#   - who picks the players in the nfl draft
#   - what is the new touchback rule in the nfl
#   - when did the nfl adopt a salary cap
#
# [07] entity='Canada'  size=7  sim=0.579
#   - when does a wrinkle in time come out in canada
#   - when was the immigration act passed in canada
#   - where are the first nations located in canada
#   - when did canada sign the un declaration of indigenous rights
#   - when did canada get rid of the death penalty
#   - how many stores does lowes have in canada
#   - what is small business tax rate in canada
#
# [08] entity='America'  size=6  sim=0.478
#   - do all private schools have uniforms in america
#   - who did america declare war on in ww1
#   - what was the purpose of the mall of america
#   - what ethnic group celebrates its contribution to america in october
#   - when was the lupus foundation of america founded
#   - when did they stop using the electric chair in america
#
# [09] entity='Harry Potter'  size=6  sim=0.614
#   - when did harry potter and the sorcerers stone take place
#   - who plays voldemort in harry potter and the philosopher's stone
#   - how tall is the actor who plays hagrid in harry potter
#   - when was harry potter and the philosophers stone published
#   - when did the first movie of harry potter come out
#   - who plays harry's mom in harry potter
#
# [10] entity='France'  size=5  sim=0.564
#   - why was the statue of liberty given to the us as a gift from france
#   - who did the central powers defeat on the eastern front before concentrating back on france
#   - why is the cockerel the symbol of france
#   - what emperor took over france after the reign of terror
#   - who abolished the monarchy and declared france a republic
#
# [11] entity='Egypt'  size=5  sim=0.573
#   - the initial unification of upper and lower egypt took place during which period
#   - what type of writing did ancient egypt use
#   - what was the most important new religious figure of the new kingdom of ancient egypt
#   - who was the ottoman governor who led egypt in the years following the napoleonic wars
#   - how long did it take to build the great pyramid of egypt
#
# [12] entity='Netflix'  size=5  sim=0.604
#   - how many seasons of the blacklist are there on netflix
#   - where does 13 reasons why take place netflix
#   - how many episodes of the killing on netflix
#   - where do they film the ranch on netflix
#   - what is the series ozark about on netflix
#
# [13] entity='Mexico'  size=4  sim=0.502
#   - when does mexico play in the winter olympics
#   - where is san miguel de allende in mexico
#   - who was elected president in mexico in 2000
#   - where are the organ mountains in new mexico
#
# [14] entity='California'  size=4  sim=0.553
#   - where does the water from the california aqueduct come from
#   - what gun does the california highway patrol use
#   - how did the california gold rush affect the growth of california
#   - where are the giant redwoods located in california
#
# [15] entity='England'  size=4  sim=0.569
#   - who brought the idea of castles to england
#   - when did the black death end in england
#   - when did the first train run in england
#   - in 1945 which party came into power in england
#
# [16] entity='South Africa'  size=4  sim=0.546
#   - where does kfc get their chicken in south africa
#   - when was corporal punishment banned in south africa
#   - who was the leader of the zulu in south africa who led the fight against the british
#   - dutch settlers in south africa were known as boers
#
# [17] entity='Philippines'  size=4  sim=0.601
#   - when did martial law in the philippines end
#   - who has the right to vote in philippines
#   - how much for a passport in the philippines
#   - what is the job of a senator in the philippines
#
# [18] entity='Japan'  size=4  sim=0.572
#   - what was the first form of manga in japan
#   - when did the us stop trading with japan
#   - what is the emperor's role in japan
#   - who negotiated an agreement with japan concerning the future of korea
#
# [19] entity='Spain'  size=3  sim=0.476
#   - is spain the second largest country in europe
#   - when is the running of the bulls held in spain
#   - the cuban revolt against spain was led by
#
# [20] entity='Florida'  size=3  sim=0.492
#   - what category was hurricane charley when it hit florida
#   - who carried florida by 537 votes in 2000
#   - where does florida natural orange juice come from

# %%
# ── FILL IN YOUR RATINGS HERE (1–5 per entity class) ─────────────────────────

entity_ratings = {
     1: None,  # China
     2: None,  # Congress
     3: None,  # Australia
     4: None,  # Nba
     5: None,  # Britain
     6: None,
     7: None,
     8: None,
     9: None,
    10: None,
    11: None,
    12: None,
    13: None,
    14: None,
    15: None,
    16: None,
    17: None,
    18: None,
    19: None,
    20: None,
}

# %%
# Entity rating summary
rated_e = {k: v for k, v in entity_ratings.items() if v is not None}
if rated_e:
    scores_e = list(rated_e.values())
    print(f'Rated {len(rated_e)}/20 entity classes')
    print(f'Mean rating:  {np.mean(scores_e):.2f} / 5.0')
    print(f'Median:       {np.median(scores_e):.1f}')
    print(f'Distribution: {dict(sorted((v, scores_e.count(v)) for v in set(scores_e)))}')
    print(f'Pass (≥3.5): {"YES" if np.mean(scores_e) >= 3.5 else "NO"}')
else:
    print('No ratings yet — fill in entity_ratings above.')
# Out:
# No ratings yet — fill in entity_ratings above.

# %% [markdown]
# ---
# ## Part 3 — Within-Class Similarity Histograms

# %%
para_sims = [c['within_class_similarity'] for c in para_classes]
entity_sims = [c['within_class_similarity'] for c in entity_classes]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(para_sims, bins=20, color='steelblue', edgecolor='white', linewidth=0.5)
axes[0].axvline(np.mean(para_sims), color='red', linestyle='--', linewidth=1.5, label=f'mean={np.mean(para_sims):.3f}')
axes[0].axvline(0.85, color='orange', linestyle=':', linewidth=1.5, label='target=0.85')
axes[0].set_title('Paraphrase Classes\nWithin-class Cosine Similarity', fontsize=12)
axes[0].set_xlabel('Mean Pairwise Cosine Similarity')
axes[0].set_ylabel('Count')
axes[0].legend()
axes[0].set_xlim(0.6, 1.0)

axes[1].hist(entity_sims, bins=10, color='coral', edgecolor='white', linewidth=0.5)
axes[1].axvline(np.mean(entity_sims), color='red', linestyle='--', linewidth=1.5, label=f'mean={np.mean(entity_sims):.3f}')
axes[1].set_title('Entity Classes\nWithin-class Cosine Similarity', fontsize=12)
axes[1].set_xlabel('Mean Pairwise Cosine Similarity')
axes[1].set_ylabel('Count')
axes[1].legend()
axes[1].set_xlim(0.3, 0.8)

plt.tight_layout()
plt.savefig(DATA_DIR / 'similarity_histograms.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved to', DATA_DIR / 'similarity_histograms.png')
# Out:
# Saved to /home/ishana/scratch/data/classes/similarity_histograms.png

# %% [markdown]
# ---
# ## Part 4 — Entity Class Size Distribution

# %%
sizes = [c['size'] for c in entity_classes]
from collections import Counter
size_dist = Counter(sizes)

fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(size_dist.keys(), size_dist.values(), color='coral', edgecolor='white')
ax.set_title('Entity Class Size Distribution', fontsize=12)
ax.set_xlabel('Queries per Class')
ax.set_ylabel('Number of Classes')
ax.set_xticks(sorted(size_dist.keys()))
plt.tight_layout()
plt.savefig(DATA_DIR / 'entity_size_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

print('Entity class size distribution:')
for sz in sorted(size_dist):
    print(f'  size {sz}: {size_dist[sz]} classes')
print(f'Total queries: {sum(sizes)}')
print(f'Mean size: {np.mean(sizes):.1f}')
# Out:
# Entity class size distribution:
#   size 3: 2 classes
#   size 4: 6 classes
#   size 5: 3 classes
#   size 6: 2 classes
#   size 7: 4 classes
#   size 8: 3 classes
# Total queries: 109
# Mean size: 5.5

# %% [markdown]
# ---
# ## Part 5 — Full Summary (copy to results/task1_class_validation.md)

# %%
rated_p = {k: v for k, v in para_ratings.items() if v is not None}
rated_e = {k: v for k, v in entity_ratings.items() if v is not None}

print('=' * 60)
print('TASK 1 — QUERY CLASS VALIDATION SUMMARY')
print('=' * 60)
print()
print('PARAPHRASE CLASSES')
print(f'  Count:                  {len(para_classes)}')
print(f'  Queries per class:      6 (1 original + 5 paraphrases)')
print(f'  Model used:             Mistral-7B-Instruct-v0.2')
print(f'  Embedding model:        BAAI/bge-large-en-v1.5')
print(f'  Within-class sim mean:  {np.mean(para_sims):.3f}')
print(f'  Within-class sim min:   {np.min(para_sims):.3f}')
print(f'  Within-class sim max:   {np.max(para_sims):.3f}')
if rated_p:
    scores_p = list(rated_p.values())
    print(f'  Manual rating (n={len(rated_p)}):   {np.mean(scores_p):.2f} / 5.0  (pass ≥4.0: {"YES" if np.mean(scores_p) >= 4.0 else "NO"})')
else:
    print(f'  Manual rating:          NOT YET RATED')
print()
print('ENTITY CLASSES')
print(f'  Count:                  {len(entity_classes)}')
sizes = [c["size"] for c in entity_classes]
print(f'  Class size range:       {min(sizes)}–{max(sizes)}  (mean {np.mean(sizes):.1f})')
print(f'  Total queries:          {sum(sizes)}')
print(f'  Embedding model:        BAAI/bge-large-en-v1.5')
print(f'  Within-class sim mean:  {np.mean(entity_sims):.3f}  (expected 0.5–0.7)')
print(f'  Within-class sim min:   {np.min(entity_sims):.3f}')
print(f'  Within-class sim max:   {np.max(entity_sims):.3f}')
if rated_e:
    scores_e = list(rated_e.values())
    print(f'  Manual rating (n={len(rated_e)}):   {np.mean(scores_e):.2f} / 5.0  (pass ≥3.5: {"YES" if np.mean(scores_e) >= 3.5 else "NO"})')
else:
    print(f'  Manual rating:          NOT YET RATED')
print()
print('FILES')
print(f'  /home/ishana/scratch/data/classes/paraphrase_classes.json')
print(f'  /home/ishana/scratch/data/classes/paraphrase_embeddings.npy')
print(f'  /home/ishana/scratch/data/classes/entity_classes.json')
print(f'  /home/ishana/scratch/data/classes/entity_embeddings.npy')
print(f'  /home/ishana/scratch/data/classes/similarity_histograms.png')
print(f'  /home/ishana/scratch/data/classes/entity_size_distribution.png')
# Out:
# ============================================================
# TASK 1 — QUERY CLASS VALIDATION SUMMARY
# ============================================================
#
# PARAPHRASE CLASSES
#   Count:                  100
#   Queries per class:      6 (1 original + 5 paraphrases)
#   Model used:             Mistral-7B-Instruct-v0.2
#   Embedding model:        BAAI/bge-large-en-v1.5
#   Within-class sim mean:  0.897
#   Within-class sim min:   0.793
#   Within-class sim max:   0.973
#   Manual rating:          NOT YET RATED
#
# ENTITY CLASSES
#   Count:                  20
#   Class size range:       3–8  (mean 5.5)
#   Total queries:          109
#   Embedding model:        BAAI/bge-large-en-v1.5
#   Within-class sim mean:  0.559  (expected 0.5–0.7)
#   Within-class sim min:   0.476
#   Within-class sim max:   0.630
#   Manual rating:          NOT YET RATED
#
# FILES
#   /home/ishana/scratch/data/classes/paraphrase_classes.json
#   /home/ishana/scratch/data/classes/paraphrase_embeddings.npy
#   /home/ishana/scratch/data/classes/entity_classes.json
#   /home/ishana/scratch/data/classes/entity_embeddings.npy
#   /home/ishana/scratch/data/classes/similarity_histograms.png
#   /home/ishana/scratch/data/classes/entity_size_distribution.png
